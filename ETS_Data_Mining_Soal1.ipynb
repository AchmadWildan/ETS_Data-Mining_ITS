# %% [markdown]
# ##**IMPORT LIBRARY**

# %%
# import Library 
import pandas as pd
import seaborn as sb
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##**INFORMASI DATASET**

# %%
df_data=pd.read_csv('/content/drive/MyDrive/Data ITS/Data Mining/ETS/Swarm_Behaviour.csv')
df_data
# Out:
#             x1      y1  xVel1  yVel1   xA1   yA1  xS1  yS1   xC1   yC1  ...  \
# 0       562.05   -0.62 -10.70  -4.33  0.00  0.00  0.0  0.0  0.00  0.00  ...
# 1       175.66  -57.09   2.31  -2.67  0.00  0.00  0.0  0.0  0.00  0.00  ...
# 2       200.16 -320.07   4.01  -6.37  0.00  0.00  0.0  0.0  0.18 -0.26  ...
# 3       316.99 -906.84   0.85   9.17 -0.17  1.03  0.0  0.0  0.00  0.00  ...
# 4      1277.68  908.54  -2.02   8.23 -1.00  1.00  0.0  0.0  0.00  0.00  ...
# ...        ...     ...    ...    ...   ...   ...  ...  ...   ...   ...  ...
# 23304  -225.85  128.99  12.19  -7.56 -1.00  0.00  0.0  0.0  0.00  0.00  ...
# 23305 -1352.02 -233.03  -0.86  -4.37 -0.07 -0.55  0.0  0.0  0.28  0.02  ...
# 23306 -1360.61 -778.11  -2.89  -1.17  0.00  0.00  0.0  0.0  0.00  0.00  ...
# 23307   987.11  615.69  -5.61  -2.92 -1.00 -1.00  0.0  0.0  0.00  0.00  ...
# 23308   938.12 -924.87  11.18   2.85  0.10 -0.02  0.0  0.0  0.06  0.31  ...
#
# ...

# %% [markdown]
# ###**Data Swarm_Behaviour = 1**

# %%
df_data[df_data.Swarm_Behaviour==1]
# Out:
#             x1      y1  xVel1  yVel1   xA1   yA1   xS1   yS1   xC1   yC1  ...  \
# 10      872.93  719.36  -0.26   7.16 -0.04  1.00  0.00  0.00 -0.04  1.00  ...
# 11    -1273.71  793.03  -0.84   8.18 -0.10  1.00  0.00  0.00 -0.27  0.96  ...
# 12    -1320.94 -738.85  -7.93  -2.31 -0.98 -0.21  0.00  0.00  0.99  0.15  ...
# 14     1070.44 -766.63  -0.34   9.57 -0.04  1.00  0.00  0.00 -0.04  1.00  ...
# 17     1342.20 -206.96  -1.65   9.27 -0.11  0.99 -1.02 -1.07  0.22  0.98  ...
# ...        ...     ...    ...    ...   ...   ...   ...   ...   ...   ...  ...
# 23280    16.00  402.90  -0.50  11.10 -0.05  1.04  0.00  0.00  0.00  0.00  ...
# 23291 -1253.48 -234.86  -7.37  -1.36 -0.56 -0.03  0.00  0.00  0.32  0.01  ...
# 23296 -1328.64 -649.53   0.02   8.64 -0.10  0.99  0.00  0.00 -0.25  0.97  ...
# 23297  -425.25  104.59  -9.43  -2.66 -0.95 -0.33  0.00  0.00 -0.97 -0.25  ...
# 23302 -1332.64  106.20  -1.41   7.45  0.02  1.00  0.00  0.00 -0.54  0.84  ...
#
# ...

# %% [markdown]
# ##**VISUALISASI DATA**

# %% [markdown]
# ###Visualisasi pada atribut x1 dan y1

# %%
plt.figure(figsize=(20,10) )
sb.scatterplot(data= df_data, x='x1', y='y1')

# %% [markdown]
# ###Visualisasi pada atribut xVel1 dan yVel1

# %%
plt.figure(figsize=(20,10) )
sb.scatterplot(data= df_data, x='xVel1', y='yVel1')

# %% [markdown]
# ###Visualisasi pada atribut xA1 dan yA1

# %%
plt.figure(figsize=(20,10) )
sb.scatterplot(data= df_data, x='xA1', y='yA1')

# %% [markdown]
# ###Visualisasi pada atribut xS1 dan yS1

# %%
plt.figure(figsize=(20,10) )
sb.scatterplot(data= df_data, x='xS1', y='yS1')

# %% [markdown]
# ###Visualisasi pada atribut xC1 dan yC1

# %%
plt.figure(figsize=(20,10) )
sb.scatterplot(data= df_data, x='xC1', y='yC1')

# %% [markdown]
# ###Ambil contoh Visualisasi pada data swarm_behaviour = 0

# %%
plt.figure(figsize=(20,10) )
data0 = df_data.iloc[1,:-3].values
x_data0 = data0[::2]
y_data0 = data0[1::2]
plt.scatter(x_data0,y_data0)

# %% [markdown]
# ###Ambil contoh Visualisasi pada data swarm_behaviour = 1

# %%
plt.figure(figsize=(20,10) )
data0 = df_data.iloc[11,:-3].values
x_data1 = data0[::2]
y_data1 = data0[1::2]
plt.scatter(x_data1,y_data1)

# %%
sns.barplot(data=df_data, x="nAC1")
